# %%
import pandas as pd

# 3.1 Load CSV from your data folder
df = pd.read_csv('/Users/honeymustard/Desktop/data/Data_Job_WA.csv')
# 3.2 Quick checks
print(df.shape)              # prints (rows, cols)
print(df.columns.tolist())   # lists column names
df.head()                    # shows first 5 rows
# Out:
# (892, 12)
# ['Job_title', 'Company', 'State', 'City', 'Min_Salary', 'Max_Salary', 'Job_Desc', 'Industry', 'Rating', 'Date_Posted', 'Valid_until', 'Job_Type']
#               Job_title                                Company State  \
# 0        Data Scientist                                ManTech    VA
# 1        Data Scientist                                  GEICO    MD
# 2        Data Scientist                      Tecolote Research    DC
# 3        Data Scientist  Systems &amp;amp; Technology Research    VA
# 4  Chief Data Scientist                                ManTech    VA
#
#           City  Min_Salary  Max_Salary  \
# 0    Chantilly      108486      145165
# 1  Chevy Chase       69285      113337
# 2   Washington       74791      102528
# 3    Arlington       94721      115685
# 4   Alexandria          -1          -1
#
#                                             Job_Desc             Industry  \
# 0  This company is in a hiring surge in response ...    Business Services
# 1  GEICO’s Data Science team uses predictive anal...            Insurance
# 2   \nData Scientist\n \n Location: Washington, D...  Aerospace & Defense
# 3  STR is a government research contractor specia...  Aerospace & Defense
# 4  This company is in a hiring surge in response ...    Business Services
#
#    Rating Date_Posted Valid_until   Job_Type
# 0     4.1  2020-04-30  2020-06-06  FULL_TIME
# 1     3.3  2020-05-02  2020-06-06  FULL_TIME
# 2     4.0  2020-05-01  2020-06-06  FULL_TIME
# 3     4.7  2020-04-25  2020-06-06  FULL_TIME
# 4     4.1  2020-05-06  2020-06-06  FULL_TIME

# %%
# 4.1 Regex replace to strip numbers at end of string
df['company_clean'] = df['Company'] \
    .str.replace(r'\s*\d+\.\d+$', '', regex=True)  # :contentReference[oaicite:2]{index=2}
# 4.2 Trim whitespace
df['company_clean'] = df['company_clean'].str.strip()  # :contentReference[oaicite:3]{index=3}
# 4.3 Verify a few examples
df[['Company','company_clean']].drop_duplicates().head(10)
# Out:
#                                     Company  \
# 0                                   ManTech
# 1                                     GEICO
# 2                         Tecolote Research
# 3     Systems &amp;amp; Technology Research
# 5                  Booz Allen Hamilton Inc.
# 6                                   Novetta
# 8                            GetWellNetwork
# 10                       The Knot Worldwide
# 11                                   Amazon
# 12  General Dynamics Information Technology
#
#                               company_clean
# 0                                   ManTech
# 1                                     GEICO
# 2                         Tecolote Research
# 3     Systems &amp;amp; Technology Research
# 5                  Booz Allen Hamilton Inc.
# 6                                   Novetta
# 8                            GetWellNetwork
# 10                       The Knot Worldwide
# 11                                   Amazon
# 12  General Dynamics Information Technology

# %%
# 5.1 Lowercase and trim
df['job_type_clean']    = df['Job_Type'].str.lower().str.strip()     # :contentReference[oaicite:4]{index=4}
df['industry_clean']    = df['Industry'].str.lower().str.strip()

# 5.2 Map synonyms to one label
job_map = {'ft':'full-time','full time':'full-time','contractor':'contract'}
df['job_type_clean'] = df['job_type_clean'].replace(job_map)         # :contentReference[oaicite:5]{index=5}

# 5.3 Inspect unique values
print(df['job_type_clean'].unique())
print(df['industry_clean'].value_counts().head(10))
# Out:
# ['full_time' 'intern' 'part_time' 'other']
# industry_clean
# business services            254
# information technology       148
# aerospace & defense          132
# biotech & pharmaceuticals     73
# government                    69
# finance                       23
# accounting & legal            13
# education                     12
# manufacturing                  9
# health care                    5
# Name: count, dtype: int64

# %%
from sklearn.preprocessing import OneHotEncoder

ohe = OneHotEncoder(handle_unknown='ignore', sparse_output=False)      # :contentReference[oaicite:7]{index=7}
categories = ['job_type_clean','industry_clean','City','State']
encoded = ohe.fit_transform(df[categories])

# Convert to DataFrame
feat_names = ohe.get_feature_names_out(categories)
df_ohe_skl = pd.DataFrame(encoded, columns=feat_names, index=df.index)

# Merge back into original DataFrame
df = pd.concat([df, df_ohe_skl], axis=1)                               # :contentReference[oaicite:8]{index=8}

# %%
set(['company_clean','job_type_clean','industry_clean']) - set(df.columns)
# Out:
# set()

# %%
df_ohe.head()
# Out:
#               Job_title                                Company  Min_Salary  \
# 0        Data Scientist                                ManTech      108486
# 1        Data Scientist                                  GEICO       69285
# 2        Data Scientist                      Tecolote Research       74791
# 3        Data Scientist  Systems &amp;amp; Technology Research       94721
# 4  Chief Data Scientist                                ManTech          -1
#
#    Max_Salary                                           Job_Desc  \
# 0      145165  This company is in a hiring surge in response ...
# 1      113337  GEICO’s Data Science team uses predictive anal...
# 2      102528   \nData Scientist\n \n Location: Washington, D...
# 3      115685  STR is a government research contractor specia...
# 4          -1  This company is in a hiring surge in response ...
#
#               Industry  Rating Date_Posted Valid_until   Job_Type  ...  \
# 0    Business Services     4.1  2020-04-30  2020-06-06  FULL_TIME  ...
# 1            Insurance     3.3  2020-05-02  2020-06-06  FULL_TIME  ...
# 2  Aerospace & Defense     4.0  2020-05-01  2020-06-06  FULL_TIME  ...
# 3  Aerospace & Defense     4.7  2020-04-25  2020-06-06  FULL_TIME  ...
# 4    Business Services     4.1  2020-05-06  2020-06-06  FULL_TIME  ...
#
#   City_Suitland  City_Tysons  City_Vienna  City_Washington  City_White Oak  \
# 0         False        False        False            False           False
# 1         False        False        False            False           False
# 2         False        False        False             True           False
# 3         False        False        False            False           False
# 4         False        False        False            False           False
#
#    State_DC  State_MD  State_NC  State_TX  State_VA
# 0     False     False     False     False      True
# 1     False      True     False     False     False
# 2      True     False     False     False     False
# 3     False     False     False     False      True
# 4     False     False     False     False      True
#
# [5 rows x 81 columns]

# %%
set(feat_names) & set(df.columns)  # should be empty before concatenation
# Out:
# {'City_Adelphi',
#  'City_Alexandria',
#  'City_Andrews AFB',
#  'City_Annandale',
#  'City_Annapolis Junction',
#  'City_Arlington',
#  'City_Beltsville',
#  'City_Bethesda',
#  'City_Bowie',
#  'City_Burke',
#  'City_Centreville',
#  'City_Chantilly',
#  'City_Chevy Chase',
#  'City_College Park',
#  'City_Columbia',
#  'City_Crystal City',
#  'City_Crystal City, state=Virginia, Virginia',
#  'City_Fairfax',
#  'City_Falls Church',
#  'City_Fort Belvoir',
#  'City_Fort Meade',
#  'City_Fulton',
#  'City_Gaithersburg',
#  'City_Germantown',
#  'City_Greenbelt',
#  'City_Herndon',
#  'City_Lanham',
#  'City_Laurel',
#  'City_Mc Lean',
#  'City_McLean',
#  'City_North Bethesda',
#  'City_Raleigh',
#  'City_Reston',
#  'City_Rockville',
#  'City_Rosslyn',
#  'City_San Antonio',
#  'City_Silver Spring',
#  'City_Springfield',
#  'City_Sterling',
#  'City_Suitland',
#  'City_Tysons',
#  'City_Vienna',
#  'City_Washington',
#  'City_White Oak',
#  'State_DC',
#  'State_MD',
#  'State_NC',
#  'State_TX',
#  'State_VA',
#  'State_nan',
#  'industry_clean_accounting & legal',
#  'industry_clean_aerospace & defense',
#  'industry_clean_biotech & pharmaceuticals',
#  'industry_clean_business services',
#  'industry_clean_education',
#  'industry_clean_finance',
#  'industry_clean_government',
#  'industry_clean_health care',
#  'industry_clean_information technology',
#  'industry_clean_insurance',
#  'industry_clean_manufacturing',
#  'industry_clean_media',
#  'industry_clean_nan',
#  'industry_clean_non-profit',
#  'industry_clean_oil, gas, energy & utilities',
#  'industry_clean_retail',
#  'industry_clean_telecommunications',
#  'industry_clean_transportation & logistics',
#  'job_type_clean_full_time',
#  'job_type_clean_intern',
#  'job_type_clean_other',
#  'job_type_clean_part_time'}

# %%
df.to_csv('/Users/honeymustard/Desktop/data/Data_Job_WA_cleaned.csv', index=False)                # :contentReference[oaicite:9]{index=9}
